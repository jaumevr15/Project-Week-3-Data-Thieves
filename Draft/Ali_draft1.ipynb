# %%
import json
import requests
import pandas as pd
import numpy as np

# %%
url = "https://api.redtube.com/?data=redtube.Videos.searchVideos&output=json"
A = requests.get(url)
B = A.json()
print(json.dumps(B, indent=4))
# Out:
# {
#     "videos": [
#         {
#             "video": {
#                 "duration": "17:07",
#                 "views": 377668,
#                 "video_id": "23867631",
#                 "rating": "88.3721",
#                 "ratings": 215,
#                 "title": "A curious son discovers her hot step mom",
#                 "url": "https://www.redtube.com/23867631",
#                 "embed_url": "https://embed.redtube.com/?id=23867631",
#                 "default_thumb": "https://ci.rdtcdn.com/m=e0YH8f/media/videos/201911/01/23867631/original/16.jpg",
#                 "thumb": "https://ei.rdtcdn.com/m=e0YH8f/media/videos/201911/01/23867631/original/16.jpg",
#                 "publish_date": "2019-11-01 06:12:42",
#                 "thumbs": [
#                     {
#                         "size": "small",
#                         "width": 120,
#                         "height": 90,
# ...

# %%
for items in B:
